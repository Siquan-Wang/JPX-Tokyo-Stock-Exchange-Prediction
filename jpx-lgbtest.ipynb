# %%
import os
from pathlib import Path

import base64

# %%
jpx_lgb = '...'

# %%
R = 5

for i in range(R):
    jpx_lgb = base64.b64decode(jpx_lgb)

# %%
path = Path('./jpx_lgb.py')
path.parent.mkdir(exist_ok=True)
path.write_bytes(jpx_lgb)

# %%
# !python jpx_lgb.py

# %%
# !rm jpx_lgb.py
